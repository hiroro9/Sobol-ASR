# %%
import pandas as pd

# %%
ST100 = pd.read_csv("output/5000/ST_K_G_100.csv", index_col=0 )
ST010 = pd.read_csv("output/5000/ST_K_G_010.csv", index_col=0 )
ST001 = pd.read_csv("output/5000/ST_K_G_001.csv", index_col=0 )
ST110 = pd.read_csv("output/5000/ST_K_G_110.csv", index_col=0 )
ST101 = pd.read_csv("output/5000/ST_K_G_101.csv", index_col=0 )
ST011 = pd.read_csv("output/5000/ST_K_G_011.csv", index_col=0 )

# %%
ST = ST100 + ST010 + ST001 + 2*ST110 + 2*ST101 + 2*ST011

# %%
ST.to_csv("output/5000/ST_total.csv")

# %%
ST100
# Out:
#               s11   s11_err       s22   s22_err       s33   s33_err  s12  \
# time[h]
# 1.0      0.584441  0.117979  0.124914  0.027255  0.127250  0.029824  0.0
# 6.0      0.649083  0.061331  0.101550  0.012877  0.102314  0.011859  0.0
# 11.0     0.669499  0.050032  0.085813  0.007042  0.087027  0.008759  0.0
# 16.0     0.680171  0.035320  0.076194  0.005874  0.077222  0.006277  0.0
# 21.0     0.687280  0.035301  0.069652  0.004562  0.070475  0.004979  0.0
# 26.0     0.692683  0.034017  0.064924  0.003909  0.065595  0.004393  0.0
# 31.0     0.697078  0.033546  0.061371  0.004704  0.061933  0.004110  0.0
# 36.0     0.700781  0.037520  0.058626  0.003777  0.059105  0.003934  0.0
# 41.0     0.703957  0.030196  0.056460  0.003633  0.056874  0.003820  0.0
# 46.0     0.706710  0.028912  0.054722  0.002873  0.055084  0.002854  0.0
# 51.0     0.709112  0.027479  0.053308  0.002961  0.053627  0.003006  0.0
# 56.0     0.711216  0.027461  0.052146  0.002352  0.052429  0.002666  0.0
# ...

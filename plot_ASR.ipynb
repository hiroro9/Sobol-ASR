# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
dirc = 100

# %%
S = pd.read_csv("output/Si_" + str(dirc) + ".csv", index_col=0 )

# %%
S
# Out:
#               s11   s11_err           s22   s22_err       s33   s33_err  s12  \
# time[h]
# 1.0      0.000170  0.004637  1.262936e-05  0.001020 -0.000042  0.000831  0.0
# 6.0      0.000249  0.002820 -2.293663e-05  0.000518 -0.000039  0.000401  0.0
# 11.0     0.000397  0.003060 -3.586318e-05  0.000486 -0.000027  0.000448  0.0
# 16.0     0.000546  0.003504 -4.271339e-05  0.000603  0.000003  0.000805  0.0
# 21.0     0.000676  0.002870 -4.374684e-05  0.000616  0.000044  0.000698  0.0
# 26.0     0.000784  0.002908 -4.054534e-05  0.000684  0.000090  0.001112  0.0
# 31.0     0.000872  0.002334 -3.478894e-05  0.000468  0.000137  0.000803  0.0
# 36.0     0.000945  0.002314 -2.775610e-05  0.000693  0.000182  0.000840  0.0
# 41.0     0.001005  0.002536 -2.030007e-05  0.000386  0.000223  0.000983  0.0
# 46.0     0.001056  0.002351 -1.294551e-05  0.000685  0.000261  0.001146  0.0
# 51.0     0.001100  0.003145 -5.989132e-06  0.000668  0.000296  0.001037  0.0
# ...

# %%
ST = S[["s11","s22","s33", "s12", "s13", "s23", "p0", "G", "K", "ts", "tv"]]
ST_err = S[["s11_err","s22_err","s33_err", "s12_err", "s13_err", "s23_err", "p0_err", "G_err", "K_err", "ts_err", "tv_err"]]

# %%
ST.plot()

# %%
f
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-129-a9fcd54b25e7> in <module>
# ----> 1 f
#
# NameError: name 'f' is not defined

# %%
ax = fig.add_subplot(111)

# %%
for i in range(0, 9):
    S.plot(ax = ax, y = S.columns[i], yerr=ST_err.columns[i+1])

plt.show()

# %%
ax.errorbar(x=ST["time[[h]]"],y=ST,yerr=ST_err)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\program\miniconda\envs\ASR\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time[[h]]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-73a0b03481fd> in <module>
# ...
